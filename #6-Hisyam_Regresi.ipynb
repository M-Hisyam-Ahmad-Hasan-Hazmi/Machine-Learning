# %%
import numpy as np
import matplotlib.pyplot as plt

# Buat dataset sederhana
np.random.seed(0)
X = 2 * np.random.rand(100, 1)  # Fitur
y = 4 + 3 * X + np.random.randn(100, 1)  # Target (dengan sedikit noise)

# Plot dataset
plt.scatter(X, y)
plt.xlabel('Fitur')
plt.ylabel('Target')
plt.title('Dataset Sederhana untuk Latihan Regresi')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# Inisialisasi model regresi linear
model = LinearRegression()

# Latih model menggunakan data
model.fit(X, y)

# Koefisien (slope) dan intersep dari model
slope = model.coef_[0][0]
intercept = model.intercept_[0]

print("Koefisien (slope):", slope)
print("Intersep:", intercept)
# Out:
# Koefisien (slope): 2.968467510701019
# Intersep: 4.222151077447231

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_squared_log_error
import numpy as np

# Prediksi target menggunakan model
y_pred = model.predict(X)

# Nilai R square
r2 = r2_score(y, y_pred)
print("Nilai R square:", r2)

# Nilai RMSE
rmse = np.sqrt(mean_squared_error(y, y_pred))
print("Nilai RMSE:", rmse)

# Nilai MAE
mae = mean_absolute_error(y, y_pred)
print("Nilai MAE:", mae)

# Nilai MSE
mse = mean_squared_error(y, y_pred)
print("Nilai MSE:", mse)

# Nilai MAPE
mape = np.mean(np.abs((y - y_pred) / y)) * 100
print("Nilai MAPE:", mape)
# Out:
# Nilai R square: 0.7469629925504755
# Nilai RMSE: 0.9962121504602561
# Nilai MAE: 0.8492581983239289
# Nilai MSE: 0.9924386487246479
# Nilai MAPE: 13.42908835971463
